# %%
NW=read.csv("~/Documents/DE/Hobo_Data/North_of_Wachapreague_(NW).csv", skip=1)
SW=read.csv("~/Documents/DE/Hobo_Data/South_of_Wachapreague_(SW).csv", skip=1)
OY=read.csv("~/Documents/DE/Hobo_Data/Oyster_(OY).csv", skip=1)
WA=read.csv("~/Documents/DE/Hobo_Data/Wallops_(WL).csv", skip=1)
WW=read.csv("~/Documents/DE/Hobo_Data/Willis_Wharf_(WW).csv", skip=1)

# %%
plot(NW$Temp...C..LGR.S.N..1191506..SEN.S.N..1191506.)
# Out:
# plot without title

# %%
plot(SW$Temp...C..LGR.S.N..10148082..SEN.S.N..10148082.)
# Out:
# plot without title

# %%
plot(WW$Temp...C..LGR.S.N..1191507..SEN.S.N..1191507.)
# Out:
# plot without title

# %%
plot(OY$Temp...C..LGR.S.N..9804012..SEN.S.N..9804012.)
# Out:
# plot without title

# %%
plot(WA$Temp...C..LGR.S.N..10148080..SEN.S.N..10148080.)
# Out:
# plot without title
